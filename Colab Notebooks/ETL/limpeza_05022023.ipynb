# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Dados/unified-data/full_table.csv')

# %%
df.shape
# Out:
# (731535, 13)

# %%
df.isna().sum()
# Out:
# municipio                    5426
# cod_municipality                0
# regiao_intermediaria            0
# cod_regiao_intermediaria        0
# cod_regiao_imediata             0
# regiao_imediata                 0
# tipo_producao                5426
# cod_variavel                 5426
# variavel                     5426
# produto                      5426
# metrica                     73270
# valor                        5426
# ano                          5426
# dtype: int64

# %%
df = df.dropna()

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                municipio  cod_municipality regiao_intermediaria  \
# 0             Abaetetuba           1500107           Abaetetuba
# 1             Abaetetuba           1500107           Abaetetuba
# 2             Abaetetuba           1500107           Abaetetuba
# 3             Abaetetuba           1500107           Abaetetuba
# 4             Abaetetuba           1500107           Abaetetuba
# ...                  ...               ...                  ...
# 731530  Vitória do Xingu           1508357             Altamira
# 731531          Xinguara           1508407             Redenção
# 731532          Xinguara           1508407             Redenção
# 731533          Xinguara           1508407             Redenção
# 731534          Xinguara           1508407             Redenção
#
#         cod_regiao_intermediaria  cod_regiao_imediata regiao_imediata  \
# 0                         150003                 1501           Belém
# 1                         150003                 1501           Belém
# 2                         150003                 1501           Belém
# 3                         150003                 1501           Belém
# 4                         150003                 1501           Belém
# ...                          ...                  ...             ...
# 731530                      1506               150018        Altamira
# 731531                      1504               150014        Xinguara
# 731532                      1504               150014        Xinguara
# 731533                      1504               150014        Xinguara
# 731534                      1504               150014        Xinguara
#
#                            tipo_producao  cod_variavel              variavel  \
# 0                               Pecuária         105.0  Efetivo dos rebanhos
# 1                               Pecuária         105.0  Efetivo dos rebanhos
# 2                               Pecuária         105.0  Efetivo dos rebanhos
# 3                               Pecuária         105.0  Efetivo dos rebanhos
# 4                               Pecuária         105.0  Efetivo dos rebanhos
# ...                                  ...           ...                   ...
# 731530  Produto das lavouras temporárias          41.0     Área de cobertura
# 731531     Área de cobertura de Floresta           3.0     Área de cobertura
# 731532                          Pastagem          15.0     Área de cobertura
# 731533  Produto das lavouras temporárias          39.0     Área de cobertura
# 731534  Produto das lavouras temporárias          41.0     Área de cobertura
#
#                produto   metrica          valor     ano
# 0               Bovino   Cabeças      28.000000  1974.0
# 1               Bovino   Cabeças      54.000000  1975.0
# 2               Bovino   Cabeças      47.000000  1976.0
# 3               Bovino   Cabeças      39.000000  1977.0
# 4               Bovino   Cabeças      10.000000  1978.0
# ...                ...       ...            ...     ...
# 731530          Outros  Hectares     366.334757  2021.0
# 731531         Florest  Hectares   67297.304704  2021.0
# 731532           Pasto  Hectares  300973.161862  2021.0
# 731533  Soja (em grão)  Hectares    1232.578321  2021.0
# 731534          Outros  Hectares    2686.891111  2021.0
#
# [639486 rows x 13 columns]

# %%
df.variavel.unique()
# Out:
# array(['Efetivo dos rebanhos', 'Quantidade produzida', 'Área colhida',
#        'Área plantada', 'Área destinada à colheita',
#        'Quantidade produzida na silvicultura', 'Área de cobertura'],
#       dtype=object)

# %%
df = df.loc[(df['variavel'] != 'Área destinada à colheita') & (df['variavel'] != 'Área plantada') & (df['variavel'] != 'Área colhida')]

# %%
df.shape
# Out:
# (275980, 13)

# %%
to_replace = {'1.1.1 - Carvão vegetal de eucalipto':'Carvão vegetal de eucalipto',
              '1.2.1 - Lenha de eucalipto':'Lenha de eucalipto',
              '1.3.1.1 - Madeira em tora de eucalipto para papel e celulose':'Madeira em tora de eucalipto para papel e celulose',
              '1.3.2.1 - Madeira em tora de eucalipto para outras finalidades':'Madeira em tora de eucalipto para outras finalidades',
              '1.3.2.3 - Madeira em tora de outras espécies para outras finalidades':'Madeira em tora de eucalipto para outras finalidades'}
df['produto'] = df.produto.replace(to_replace)
df
# Out:
# <ipython-input-12-a7754cb90b74>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['produto'] = df.produto.replace(to_replace)
#                municipio  cod_municipality regiao_intermediaria  \
# 0             Abaetetuba           1500107           Abaetetuba
# 1             Abaetetuba           1500107           Abaetetuba
# 2             Abaetetuba           1500107           Abaetetuba
# 3             Abaetetuba           1500107           Abaetetuba
# 4             Abaetetuba           1500107           Abaetetuba
# ...                  ...               ...                  ...
# 731530  Vitória do Xingu           1508357             Altamira
# 731531          Xinguara           1508407             Redenção
# 731532          Xinguara           1508407             Redenção
# 731533          Xinguara           1508407             Redenção
# 731534          Xinguara           1508407             Redenção
#
#         cod_regiao_intermediaria  cod_regiao_imediata regiao_imediata  \
# 0                         150003                 1501           Belém
# 1                         150003                 1501           Belém
# 2                         150003                 1501           Belém
# 3                         150003                 1501           Belém
# 4                         150003                 1501           Belém
# ...                          ...                  ...             ...
# 731530                      1506               150018        Altamira
# 731531                      1504               150014        Xinguara
# 731532                      1504               150014        Xinguara
# 731533                      1504               150014        Xinguara
# 731534                      1504               150014        Xinguara
#
#                            tipo_producao  cod_variavel              variavel  \
# 0                               Pecuária         105.0  Efetivo dos rebanhos
# 1                               Pecuária         105.0  Efetivo dos rebanhos
# 2                               Pecuária         105.0  Efetivo dos rebanhos
# 3                               Pecuária         105.0  Efetivo dos rebanhos
# 4                               Pecuária         105.0  Efetivo dos rebanhos
# ...                                  ...           ...                   ...
# 731530  Produto das lavouras temporárias          41.0     Área de cobertura
# 731531     Área de cobertura de Floresta           3.0     Área de cobertura
# 731532                          Pastagem          15.0     Área de cobertura
# 731533  Produto das lavouras temporárias          39.0     Área de cobertura
# 731534  Produto das lavouras temporárias          41.0     Área de cobertura
#
#                produto   metrica          valor     ano
# 0               Bovino   Cabeças      28.000000  1974.0
# 1               Bovino   Cabeças      54.000000  1975.0
# 2               Bovino   Cabeças      47.000000  1976.0
# 3               Bovino   Cabeças      39.000000  1977.0
# 4               Bovino   Cabeças      10.000000  1978.0
# ...                ...       ...            ...     ...
# 731530          Outros  Hectares     366.334757  2021.0
# 731531         Florest  Hectares   67297.304704  2021.0
# 731532           Pasto  Hectares  300973.161862  2021.0
# 731533  Soja (em grão)  Hectares    1232.578321  2021.0
# 731534          Outros  Hectares    2686.891111  2021.0
#
# [275980 rows x 13 columns]

# %%
df.to_csv('/content/drive/MyDrive/Dados/unified-data/full_table_05022023.csv', index=False)
