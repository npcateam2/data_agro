# %%
import pandas as pd

# %%
# !pip install Texttable
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Dados/Dados_SIDRA/table_full.csv')
df = df.dropna(0, subset=['produto'])
# Out:
# <ipython-input-13-0a2408b01637>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   df = df.dropna(0, subset=['produto'])
# ...

# %%
df_latex = df.loc[(df['tipo_producao'] == 'Produto das lavouras temporárias') | (df['tipo_producao'] == 'Pecuária')]

# %%
print(df_latex.sample(10).to_latex(index=False))
# Out:
# \begin{tabular}{lrlrrllrlrlrlrr}
# \toprule
#                   cidade &  cod\_cidade &  nome\_rgi &  cod\_rgi &  cod\_rgint & nome\_rgint &                    tipo\_producao &  cod\_variavel &             variavel &  cod\_produto &             produto &  cod\_metrica &   metrica &  valor &    ano \\
# \midrule
#     Santa Izabel do Pará &     1506500 &     Belém &   150001 &       1501 &      Belém & Produto das lavouras temporárias &         214.0 & Quantidade produzida &       2694.0 &         Batata-doce &       1017.0 & Toneladas &    0.0 & 1987.0 \\
#      Santana do Araguaia &     1506708 &  Redenção &   150012 &       1504 &   Redenção & Produto das lavouras temporárias &         214.0 & Quantidade produzida &       2706.0 &       Malva (fibra) &       1017.0 & Toneladas &    0.0 & 2001.0 \\
# ...

# %%
from texttable import Texttable

# %%
table.set_cols_align(["c"] * 15)
table.set_deco(Texttable.HEADER | Texttable.VLINES)
table.add_rows(rows)

# %%
# Out:
# <ipython-input-3-dfacd0d50b23>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   df = df.dropna(0, subset=['produto'])
#             cidade  cod_cidade    nome_rgi  cod_rgi  cod_rgint nome_rgint  \
# 0       Abaetetuba     1500107  Abaetetuba   150003       1501      Belém
# 1       Abaetetuba     1500107  Abaetetuba   150003       1501      Belém
# 2       Abaetetuba     1500107  Abaetetuba   150003       1501      Belém
# 3       Abaetetuba     1500107  Abaetetuba   150003       1501      Belém
# 4       Abaetetuba     1500107  Abaetetuba   150003       1501      Belém
# ...            ...         ...         ...      ...        ...        ...
# 698539    Xinguara     1508407    Xinguara   150014       1504   Redenção
# 698540    Xinguara     1508407    Xinguara   150014       1504   Redenção
# 698541    Xinguara     1508407    Xinguara   150014       1504   Redenção
# ...

# %%
for i in df.tipo_producao.unique():
    print('='*30)
    print(i)
    print('-'*30)
    for j in df.loc[df['tipo_producao'] == i].produto.unique():
        print('\t',j)
# Out:
# ...
# Pecuária
# ------------------------------
# 	 Bovino
# 	 Bubalino
# 	 Equino
# 	 Caprino
# 	 Ovino
# ...
# Produto das lavouras temporárias
# ------------------------------
# 	 Abacaxi*
# 	 Amendoim (em casca)
# 	 Arroz (em casca)
# 	 Batata-doce
# 	 Cana-de-açúcar
# 	 Cebola
# 	 Feijão (em grão)
# 	 Fumo (em folha)
# 	 Malva (fibra)
# 	 Melancia
# 	 Milho (em grão)
# 	 Soja (em grão)
# 	 Sorgo (em grão)
# 	 Tomate
# ...
# Produto das lavouras permanentes
# ------------------------------
# 	 Açaí
# 	 Banana (cacho)
# 	 Borracha (látex coagulado)
# 	 Cacau (em amêndoa)
# 	 Café (em grão) Total
# 	 Café (em grão) Arábica
# 	 Castanha de caju
# 	 Coco-da-baía*
# 	 Goiaba
# 	 Laranja
# 	 Limão
# 	 Mamão
# 	 Maracujá
# 	 Palmito
# 	 Pimenta-do-reino
# 	 Tangerina
# 	 Urucum (semente)
# ...
# Silvicultura
# ------------------------------
# 	 1.1.1 - Carvão vegetal de eucalipto
# 	 1.2.1 - Lenha de eucalipto
# 	 1.3.1.1 - Madeira em tora de eucalipto para papel e celulose
# ...
