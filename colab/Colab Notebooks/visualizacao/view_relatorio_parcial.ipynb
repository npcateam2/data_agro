# %% [markdown]
# # Import libaries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
sns.set_style('darkgrid')

# %% [markdown]
# # Data loading

# %%
df = pd.read_csv('/content/drive/MyDrive/Dados/unified-data/full_table_05022023.csv')

# %%
df['variavel'].unique()
# Out:
# array(['Efetivo dos rebanhos', 'Quantidade produzida',
#        'Quantidade produzida na silvicultura', 'Área de cobertura'],
#       dtype=object)

# %% [markdown]
# # Declaração de funções (Não alterar)

# %%
def plot_tipo_producao(df, tipo_producao_1, tipo_producao_2, variavel_1, variavel_2):

    df_wide = pd.pivot_table(df, columns = 'variavel', values = 'valor',aggfunc=np.sum,
                        index = ['produto','ano', 'tipo_producao'], fill_value = 0)
    df_wide = df_wide.reset_index()

    df_plot = df_wide.loc[(df_wide['tipo_producao'] == tipo_producao_1) | (df_wide['tipo_producao'] == tipo_producao_2) & (df_wide['ano'] >= 1985)].groupby('ano', as_index=False).sum()
    df_plot = df_plot.loc[(df_plot['ano'] >= 1985)]

    ax = sns.lineplot(x = df_plot['ano'], y = df_plot[variavel_1], color='g')

    ax1 = ax.twinx()
    ax2 = sns.lineplot(x = df_plot['ano'], y = df_plot[variavel_2], color ='b')

    ax2.grid(False)
    ax.ticklabel_format(style='plain', axis='y')
    ax2.ticklabel_format(style='plain', axis='y')
    ax.legend(handles=[Line2D([], [], marker='_', color="g", label='Cabeças'), Line2D([], [], marker='_', color="b", label='Hectares')])

    ax.set_xticks(list(range(1984,2022,1)))
    ax2.set_xticks(list(range(1984,2022,1)))

    plt.xlim((1984, 2022))

    plt.ylim(bottom=0)



    plt.title('Número de cabeças e cobertura de pastagem no decorres dos anos para o estado do Pará', fontdict= {'size':13}, 
            y = 1.03, fontweight="bold")

    ax.set_xticklabels(
        labels=list(range(1984,2022,1)), rotation=70)
    ax2.set_xticklabels(
        labels=list(range(1984,2022,1)), rotation=70)

    ax.set_ylabel('Número de cabeças', fontweight="bold")
    ax2.set_ylabel('Cobertura de pastagem', fontweight="bold")

    ax.yaxis.label.set_color('green')
    ax2.yaxis.label.set_color('blue')

    ax.tick_params(colors='green', axis='y') 
    ax2.tick_params(colors='blue', axis='y') 

    plt.show()

# %%
def filtrar_tabela(df, filtrar_por, area, filtros:dict, limitar_ano=True):
# 	cod_municipality	regiao_intermediaria	cod_regiao_intermediaria	cod_regiao_imediata	regiao_imediata	tipo_producao	cod_variavel	variavel	produto	valor	ano

  '''
  # Filtro de tabela
  ```
  filtrar_tabela(data, filtrar_por, area, filtros:dict, limitar_ano=True)
  ```

  Filtra a tabela de dados full_table.csv



  Parâmetros: df: DataFrame
                  
                  Objeto DataFrame localizado em:  /content/drive/MyDrive/Dados/unified-data/*.csv
              
              filtrar_por: str
                  
                  Aplica filtro para limitar a dimensão geográfica dos dados filtrados. Aceita 3 valores:

                    Pará: Filtro em todo o estado
                    imediata: Utiliza dimenssão de região imediata
                    intermediaria: Utiliza dimnessão de região intermediária
                    municipio: Utiliza dimenssão de município

              area: str ou list

                  Área que o filtro será aplicado. Deve coincidir com os registros presentes no DataFrame. Caso o parâmetro *filtrar_por* seja especificado como "municipio", as área devem estar presentes na dimenssão do município
              
              filtros: dict

                  Aplica diversos filtros com base em um dicionário Python. As chaves passadas devem corresponder a uma coluna e o valor deve corresponder ao filtro de igualdade aplicado.

                  Exemplo:
                    
                    Para retornar somente os registros com o tipo_de_produção "Pecuária" do produto de bovinos, o dicionário deve ser o seguinte:

                    ````
                    {"tipo_producao":"Pecuária", "produto":"Bovino"}
                    ````

              limitar_ano: Boleano

                  Filtra os registros considerando o ano maior ou igual a 1985. Se False, irá considerar também os anos anteriores\n\n\n

  

  Retorna: pandas.DataFrame
  '''



  if limitar_ano:
    df = df.loc[df['ano'] >= 1985]

  if filtrar_por == 'Pará':
    df_temp = df

  elif filtrar_por == 'imediata':
    if type(area) == list:
      df_regi = []
      for i in area:
        df_area.append(df.loc[df['regiao_imediata'] == i])
      df_temp = pd.concat(df_area)
    elif type(area) == str:
      df_temp = df.loc[df['regiao_imediata'] == area]
    
  elif filtrar_por == 'intermediaria':
    if type(area) == list:
      df_area = []
      for i in area:
        df_area.append(df.loc[df['regiao_intermediaria'] == i])
      df_temp = pd.concat(df_area)
    elif type(area) == str:
      df_temp = df.loc[df['regiao_intermediaria'] == area]


  elif filtrar_por == 'municipio':
    if type(area) == list:
      df_area = []
      for i in area:
        df_area.append(df.loc[df['municipio'] == i])
      df_temp = pd.concat(df_area)
    elif type(area) == str:
      df_temp = df.loc[df['municipio'] == area]

  list_df_plot = []

  for k, v in filtros.items():
    list_df_plot.append(df_temp.loc[df_temp[k] == v])
  df_temp = pd.concat(list_df_plot)
  df_temp = df_temp.drop_duplicates()
  return df_temp.reset_index(drop = True)
  
def visulizar_opcoes(df, coluna):
  for i in df[coluna].unique():
    print(f'{i}')

# %% [markdown]
# # Sandbox

# %%
visulizar_opcoes(df, 'tipo_producao')
# Out:
# Pecuária
# Produto das lavouras temporárias
# Produto das lavouras permanentes
# Silvicultura
# Área de cobertura de Floresta
# Pastagem

# %%
df_test = filtrar_tabela(df, 'municipio', 'Paragominas', filtros = {'tipo_producao':'Pecuária', 'produto':'Bovino'})
df_test
# Out:
#        municipio  cod_municipality regiao_intermediaria  \
# 0    Paragominas           1505502          Paragominas
# 1    Paragominas           1505502          Paragominas
# 2    Paragominas           1505502          Paragominas
# 3    Paragominas           1505502          Paragominas
# 4    Paragominas           1505502          Paragominas
# ..           ...               ...                  ...
# 365  Paragominas           1505502          Paragominas
# 366  Paragominas           1505502          Paragominas
# 367  Paragominas           1505502          Paragominas
# 368  Paragominas           1505502          Paragominas
# 369  Paragominas           1505502          Paragominas
#
#      cod_regiao_intermediaria  cod_regiao_imediata regiao_imediata  \
# 0                      150007                 1502       Castanhal
# 1                      150007                 1502       Castanhal
# 2                      150007                 1502       Castanhal
# 3                      150007                 1502       Castanhal
# 4                      150007                 1502       Castanhal
# ..                        ...                  ...             ...
# 365                    150007                 1502       Castanhal
# 366                    150007                 1502       Castanhal
# 367                    150007                 1502       Castanhal
# 368                    150007                 1502       Castanhal
# 369                    150007                 1502       Castanhal
#
#     tipo_producao  cod_variavel              variavel  cod_produto produto  \
# 0        Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# 1        Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# 2        Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# 3        Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# 4        Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# ..            ...           ...                   ...          ...     ...
# 365      Pecuária         105.0  Efetivo dos rebanhos         -1.0   Ovino
# 366      Pecuária         105.0  Efetivo dos rebanhos         -1.0   Ovino
# 367      Pecuária         105.0  Efetivo dos rebanhos         -1.0   Ovino
# 368      Pecuária         105.0  Efetivo dos rebanhos         -1.0   Ovino
# 369      Pecuária         105.0  Efetivo dos rebanhos         -1.0   Ovino
#
#      cod_metrica   metrica     valor     ano
# 0           24.0   Cabeças  385641.0  1985.0
# 1           24.0   Cabeças  449860.0  1986.0
# 2           24.0   Cabeças  469380.0  1987.0
# 3           24.0   Cabeças  505000.0  1988.0
# 4           24.0   Cabeças  513145.0  1989.0
# ..           ...       ...       ...     ...
# 365          1.0  Hectares    6722.0  2017.0
# 366          1.0  Hectares    5380.0  2018.0
# 367          1.0  Hectares    5373.0  2019.0
# 368          1.0  Hectares    2277.0  2020.0
# 369          1.0  Hectares    3745.0  2021.0
#
# [370 rows x 15 columns]

# %%
ax = sns.lineplot(x =  df_test['ano'], y = df_test['valor'])
ax.set_xlabel('Ano')
ax.set_ylabel('Qtd')

# ax.set_title(f'Quantidade de {metrica} de {produto} produzidas\n na(s) cidade(s) de {cidade} dos anos de {int(df_test.ano.min())} até {int(df_test.ano.max())}')
# Out:
# Text(0, 0.5, 'Qtd')

# %%
# Tirar cidade n/ pará
# Coluna produto/cobertura - Dados mapbiomas, Métrica hectares
# Adiciona MapBiomas
# Ajuste de gráficos
# Filtrar diversas dimensionalidades geográficas
# Incluir estatística descritivas de acordo com dados geográficos

# %% [markdown]
# # Workspace (15/02/2023)

# %%
df.head()
# Out:
#     municipio  cod_municipality regiao_intermediaria  \
# 0  Abaetetuba           1500107           Abaetetuba
# 1  Abaetetuba           1500107           Abaetetuba
# 2  Abaetetuba           1500107           Abaetetuba
# 3  Abaetetuba           1500107           Abaetetuba
# 4  Abaetetuba           1500107           Abaetetuba
#
#    cod_regiao_intermediaria  cod_regiao_imediata regiao_imediata  \
# 0                    150003                 1501           Belém
# 1                    150003                 1501           Belém
# 2                    150003                 1501           Belém
# 3                    150003                 1501           Belém
# 4                    150003                 1501           Belém
#
#   tipo_producao  cod_variavel              variavel  cod_produto produto  \
# 0      Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# 1      Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# 2      Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# 3      Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# 4      Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
#
#    cod_metrica  metrica  valor     ano
# 0         24.0  Cabeças   28.0  1974.0
# 1         24.0  Cabeças   54.0  1975.0
# 2         24.0  Cabeças   47.0  1976.0
# 3         24.0  Cabeças   39.0  1977.0
# 4         24.0  Cabeças   10.0  1978.0

# %%
df.produto.unique()
# Out:
# array(['Bovino', 'Bubalino', 'Equino', 'Caprino', 'Ovino', 'Abacaxi*',
#        'Amendoim (em casca)', 'Arroz (em casca)', 'Batata-doce',
#        'Cana-de-açúcar', 'Cebola', 'Feijão (em grão)', 'Fumo (em folha)',
#        'Malva (fibra)', 'Melancia', 'Milho (em grão)', 'Soja (em grão)',
#        'Sorgo (em grão)', 'Tomate', 'Açaí', 'Banana (cacho)',
#        'Borracha (látex coagulado)', 'Cacau (em amêndoa)',
#        'Café (em grão) Total', 'Café (em grão) Arábica',
#        'Castanha de caju', 'Coco-da-baía*', 'Goiaba', 'Laranja', 'Limão',
#        'Mamão', 'Maracujá', 'Palmito', 'Pimenta-do-reino', 'Tangerina',
#        'Urucum (semente)', '1.1.1 - Carvão vegetal de eucalipto',
#        '1.2.1 - Lenha de eucalipto',
#        '1.3.1.1 - Madeira em tora de eucalipto para papel e celulose',
#        '1.3.2.1 - Madeira em tora de eucalipto para outras finalidades',
#        '1.3.2.3 - Madeira em tora de outras espécies para outras finalidades',
#        'Carvão vegetal de eucalipto', 'Lenha de eucalipto',
#        'Madeira em tora de eucalipto para papel e celulose',
#        'Madeira em tora de eucalipto para outras finalidades',
#        'Madeira em tora de outras espécies para outras finalidades',
#        'Florest', 'Pasto', 'Outros'], dtype=object)

# %%
to_replace = {'1.1.1 - Carvão vegetal de eucalipto':'Carvão vegetal de eucalipto',
              '1.2.1 - Lenha de eucalipto':'Lenha de eucalipto',
              '1.3.1.1 - Madeira em tora de eucalipto para papel e celulose':'Madeira em tora de eucalipto para papel e celulose',
              '1.3.2.1 - Madeira em tora de eucalipto para outras finalidades':'Madeira em tora de eucalipto para outras finalidades',
              '1.3.2.3 - Madeira em tora de outras espécies para outras finalidades':'Madeira em tora de eucalipto para outras finalidades'}
df['produto'] = df.produto.replace(to_replace)
df
# Out:
#                municipio  cod_municipality regiao_intermediaria  \
# 0             Abaetetuba           1500107           Abaetetuba
# 1             Abaetetuba           1500107           Abaetetuba
# 2             Abaetetuba           1500107           Abaetetuba
# 3             Abaetetuba           1500107           Abaetetuba
# 4             Abaetetuba           1500107           Abaetetuba
# ...                  ...               ...                  ...
# 731530  Vitória do Xingu           1508357             Altamira
# 731531          Xinguara           1508407             Redenção
# 731532          Xinguara           1508407             Redenção
# 731533          Xinguara           1508407             Redenção
# 731534          Xinguara           1508407             Redenção
#
#         cod_regiao_intermediaria  cod_regiao_imediata regiao_imediata  \
# 0                         150003                 1501           Belém
# 1                         150003                 1501           Belém
# 2                         150003                 1501           Belém
# 3                         150003                 1501           Belém
# 4                         150003                 1501           Belém
# ...                          ...                  ...             ...
# 731530                      1506               150018        Altamira
# 731531                      1504               150014        Xinguara
# 731532                      1504               150014        Xinguara
# 731533                      1504               150014        Xinguara
# 731534                      1504               150014        Xinguara
#
#                            tipo_producao  cod_variavel              variavel  \
# 0                               Pecuária         105.0  Efetivo dos rebanhos
# 1                               Pecuária         105.0  Efetivo dos rebanhos
# 2                               Pecuária         105.0  Efetivo dos rebanhos
# 3                               Pecuária         105.0  Efetivo dos rebanhos
# 4                               Pecuária         105.0  Efetivo dos rebanhos
# ...                                  ...           ...                   ...
# 731530  Produto das lavouras temporárias          41.0     Área de cobertura
# 731531     Área de cobertura de Floresta           3.0     Área de cobertura
# 731532                          Pastagem          15.0     Área de cobertura
# 731533  Produto das lavouras temporárias          39.0     Área de cobertura
# 731534  Produto das lavouras temporárias          41.0     Área de cobertura
#
#                produto          valor     ano
# 0               Bovino      28.000000  1974.0
# 1               Bovino      54.000000  1975.0
# 2               Bovino      47.000000  1976.0
# 3               Bovino      39.000000  1977.0
# 4               Bovino      10.000000  1978.0
# ...                ...            ...     ...
# 731530          Outros     366.334757  2021.0
# 731531         Florest   67297.304704  2021.0
# 731532           Pasto  300973.161862  2021.0
# 731533  Soja (em grão)    1232.578321  2021.0
# 731534          Outros    2686.891111  2021.0
#
# [731535 rows x 12 columns]

# %%
df.produto.unique()
# Out:
# array(['Bovino', 'Bubalino', 'Equino', 'Caprino', 'Ovino', 'Abacaxi*',
#        'Amendoim (em casca)', 'Arroz (em casca)', 'Batata-doce',
#        'Cana-de-açúcar', 'Cebola', 'Feijão (em grão)', 'Fumo (em folha)',
#        'Malva (fibra)', 'Melancia', 'Milho (em grão)', 'Soja (em grão)',
#        'Sorgo (em grão)', 'Tomate', 'Açaí', 'Banana (cacho)',
#        'Borracha (látex coagulado)', 'Cacau (em amêndoa)',
#        'Café (em grão) Total', 'Café (em grão) Arábica',
#        'Castanha de caju', 'Coco-da-baía*', 'Goiaba', 'Laranja', 'Limão',
#        'Mamão', 'Maracujá', 'Palmito', 'Pimenta-do-reino', 'Tangerina',
#        'Urucum (semente)', 'Carvão vegetal de eucalipto',
#        'Lenha de eucalipto',
#        'Madeira em tora de eucalipto para papel e celulose',
#        'Madeira em tora de eucalipto para outras finalidades',
#        'Madeira em tora de outras espécies para outras finalidades',
#        'Florest', 'Pasto', 'Outros'], dtype=object)

# %%
df_wide = pd.pivot_table(df, columns = 'variavel', values = 'valor',aggfunc=np.sum,
                        index = ['produto','ano', 'tipo_producao', 'metrica'], fill_value = 0)
df_wide = df_wide.reset_index()
df_wide
# Out:
# variavel           produto     ano                     tipo_producao  \
# 0                 Abacaxi*  1974.0  Produto das lavouras temporárias
# 1                 Abacaxi*  1974.0  Produto das lavouras temporárias
# 2                 Abacaxi*  1975.0  Produto das lavouras temporárias
# 3                 Abacaxi*  1975.0  Produto das lavouras temporárias
# 4                 Abacaxi*  1976.0  Produto das lavouras temporárias
# ...                    ...     ...                               ...
# 3815      Urucum (semente)  2019.0  Produto das lavouras permanentes
# 3816      Urucum (semente)  2020.0  Produto das lavouras permanentes
# 3817      Urucum (semente)  2020.0  Produto das lavouras permanentes
# 3818      Urucum (semente)  2021.0  Produto das lavouras permanentes
# 3819      Urucum (semente)  2021.0  Produto das lavouras permanentes
#
# variavel    metrica  Efetivo dos rebanhos  Quantidade produzida  \
# 0          Hectares                     0                   888
# 1         Toneladas                     0                   888
# 2          Hectares                     0                  1146
# 3         Toneladas                     0                  1146
# 4          Hectares                     0                   988
# ...             ...                   ...                   ...
# 3815      Toneladas                     0                  1105
# 3816       Hectares                     0                   990
# 3817      Toneladas                     0                   990
# 3818       Hectares                     0                   940
# 3819      Toneladas                     0                   940
#
# variavel  Quantidade produzida na silvicultura  Área de cobertura
# 0                                            0                0.0
# 1                                            0                0.0
# 2                                            0                0.0
# 3                                            0                0.0
# 4                                            0                0.0
# ...                                        ...                ...
# 3815                                         0                0.0
# 3816                                         0                0.0
# 3817                                         0                0.0
# 3818                                         0                0.0
# 3819                                         0                0.0
#
# [3820 rows x 8 columns]

# %%
df.to_csv('/content/drive/MyDrive/Dados/unified-data/full_table_17022023.csv', index=False)

# %%
plot_tipo_producao(df, 'Produto das lavouras temporárias', 'Produto das lavouras permanentes',
                    'Quantidade produzida', 'Área de cobertura')

# %%
df.variavel.unique()
# Out:
# array(['Efetivo dos rebanhos', 'Quantidade produzida',
#        'Quantidade produzida na silvicultura', 'Área de cobertura'],
#       dtype=object)

# %%
df_plot = df_wide.loc[(df_wide['tipo_producao'] == 'Pecuária') | (df_wide['tipo_producao'] == 'Pastagem') & (df_wide['ano'] >= 1985)].groupby('ano', as_index=False).sum()
df_plot = df_plot.loc[(df_plot['ano'] >= 1985)]
df_plot

# %%
sns.set(rc={'figure.figsize':(10,6)})

# %% [markdown]
# ## Pastagem e pecuária

# %%
ax = sns.lineplot(x = df_plot['ano'], y = df_plot['Efetivo dos rebanhos'], color='g')

ax1 = ax.twinx()
ax2 = sns.lineplot(x = df_plot['ano'], y = df_plot['Área de cobertura'], color ='b')

ax2.grid(False)
ax.ticklabel_format(style='plain', axis='y')
ax2.ticklabel_format(style='plain', axis='y')
ax.legend(handles=[Line2D([], [], marker='_', color="g", label='Cabeças'), Line2D([], [], marker='_', color="b", label='Hectares')])

ax.set_xticks(list(range(1984,2022,1)))
ax2.set_xticks(list(range(1984,2022,1)))

plt.xlim((1984, 2022))

plt.ylim(bottom=0)



plt.title('Número de cabeças e cobertura de pastagem no decorres dos anos para o estado do Pará', fontdict= {'size':13}, 
          y = 1.03, fontweight="bold")

ax.set_xticklabels(
    labels=list(range(1984,2022,1)), rotation=70)
ax2.set_xticklabels(
    labels=list(range(1984,2022,1)), rotation=70)

ax.set_ylabel('Efetivo dos rebanhos (Cabeças)', fontweight="bold")
ax2.set_ylabel('Área de cobertura (Hectares)', fontweight="bold")

ax.yaxis.label.set_color('green')
ax2.yaxis.label.set_color('blue')

ax.tick_params(colors='green', axis='y') 
ax2.tick_params(colors='blue', axis='y') 

plt.show()

# %%
sns.heatmap(df_plot[['Efetivo dos rebanhos', 'Área de cobertura']].corr(),annot=True, cmap='cividis')
plt.xlabel('')
plt.ylabel('')
plt.title('Correlação de Pearson entre o número de\n rebanho e a cobertura de pastagens no estado do Pará',
          y = 2)
# Out:
# Text(0.5, 2, 'Correlação de Pearson entre o número de\n rebanho e a cobertura de pastagens no estado do Pará')

# %%
visulizar_opcoes(df, coluna = 'tipo_producao')
# Out:
# Pecuária
# Produto das lavouras temporárias
# Produto das lavouras permanentes
# Silvicultura
# Área de cobertura de Floresta
# Pastagem

# %%
visulizar_opcoes(df, coluna = 'produto')
# Out:
# Bovino
# Bubalino
# Equino
# Caprino
# Ovino
# Abacaxi*
# Amendoim (em casca)
# Arroz (em casca)
# Batata-doce
# Cana-de-açúcar
# Cebola
# Feijão (em grão)
# Fumo (em folha)
# Malva (fibra)
# Melancia
# Milho (em grão)
# Soja (em grão)
# Sorgo (em grão)
# Tomate
# Açaí
# Banana (cacho)
# Borracha (látex coagulado)
# Cacau (em amêndoa)
# Café (em grão) Total
# Café (em grão) Arábica
# Castanha de caju
# Coco-da-baía*
# Goiaba
# Laranja
# Limão
# Mamão
# Maracujá
# Palmito
# Pimenta-do-reino
# Tangerina
# Urucum (semente)
# Carvão vegetal de eucalipto
# Lenha de eucalipto
# Madeira em tora de eucalipto para papel e celulose
# Madeira em tora de eucalipto para outras finalidades
# Madeira em tora de outras espécies para outras finalidades
# Florest
# Pasto
# Outros

# %%
df_soja = df.loc[df['produto'] == 'Soja (em grão)']

# %%
df_soja
# Out:
#                municipio  cod_municipality regiao_intermediaria  \
# 768           Abaetetuba           1500107           Abaetetuba
# 769           Abaetetuba           1500107           Abaetetuba
# 770           Abaetetuba           1500107           Abaetetuba
# 771           Abaetetuba           1500107           Abaetetuba
# 772           Abaetetuba           1500107           Abaetetuba
# ...                  ...               ...                  ...
# 525624            Uruará           1508159             Altamira
# 525628             Vigia           1508209                Belém
# 525633             Viseu           1508308            Castanhal
# 525637  Vitória do Xingu           1508357             Altamira
# 525641          Xinguara           1508407             Redenção
#
#         cod_regiao_intermediaria  cod_regiao_imediata regiao_imediata  \
# 768                       150003                 1501           Belém
# 769                       150003                 1501           Belém
# 770                       150003                 1501           Belém
# 771                       150003                 1501           Belém
# 772                       150003                 1501           Belém
# ...                          ...                  ...             ...
# 525624                      1506               150018        Altamira
# 525628                      1501               150001           Belém
# 525633                      1502               150005        Bragança
# 525637                      1506               150018        Altamira
# 525641                      1504               150014        Xinguara
#
#                            tipo_producao  cod_variavel              variavel  \
# 768     Produto das lavouras temporárias         214.0  Quantidade produzida
# 769     Produto das lavouras temporárias         214.0  Quantidade produzida
# 770     Produto das lavouras temporárias         214.0  Quantidade produzida
# 771     Produto das lavouras temporárias         214.0  Quantidade produzida
# 772     Produto das lavouras temporárias         214.0  Quantidade produzida
# ...                                  ...           ...                   ...
# 525624  Produto das lavouras temporárias          39.0     Área de cobertura
# 525628  Produto das lavouras temporárias          39.0     Área de cobertura
# 525633  Produto das lavouras temporárias          39.0     Área de cobertura
# 525637  Produto das lavouras temporárias          39.0     Área de cobertura
# 525641  Produto das lavouras temporárias          39.0     Área de cobertura
#
#         cod_produto         produto  cod_metrica    metrica        valor  \
# 768          2713.0  Soja (em grão)       1017.0  Toneladas     0.000000
# 769          2713.0  Soja (em grão)       1017.0  Toneladas     0.000000
# 770          2713.0  Soja (em grão)       1017.0  Toneladas     0.000000
# 771          2713.0  Soja (em grão)       1017.0  Toneladas     0.000000
# 772          2713.0  Soja (em grão)       1017.0  Toneladas     0.000000
# ...             ...             ...          ...        ...          ...
# 525624         -1.0  Soja (em grão)          1.0   Hectares  4051.138800
# 525628         -1.0  Soja (em grão)          1.0   Hectares     4.290440
# 525633         -1.0  Soja (em grão)          1.0   Hectares    63.458213
# 525637         -1.0  Soja (em grão)          1.0   Hectares    21.607314
# 525641         -1.0  Soja (em grão)          1.0   Hectares  1232.578321
#
#            ano
# 768     1974.0
# 769     1975.0
# 770     1976.0
# 771     1977.0
# 772     1978.0
# ...        ...
# 525624  2021.0
# 525628  2021.0
# 525633  2021.0
# 525637  2021.0
# 525641  2021.0
#
# [17517 rows x 15 columns]

# %%
def plot_tipo_producao(df, tipo_producao_1, tipo_producao_2, variavel_1, variavel_2 , titulo, y1_label, y2_label, y1_legend, y2_legend, return_df):

    df_wide = pd.pivot_table(df, columns = 'variavel', values = 'valor',aggfunc=np.sum,
                        index = ['produto','ano', 'tipo_producao'], fill_value = 0)
    df_wide = df_wide.reset_index()

    df_plot = df_wide.loc[(df_wide['tipo_producao'] == tipo_producao_1) | (df_wide['tipo_producao'] == tipo_producao_2) & (df_wide['ano'] >= 1985)].groupby('ano', as_index=False).sum()
    df_plot = df_plot.loc[(df_plot['ano'] >= 1985)]

    if return_df == True:
        return df_plot

    ax = sns.lineplot(x = df_plot['ano'], y = df_plot[variavel_1], color='g')

    ax1 = ax.twinx()
    ax2 = sns.lineplot(x = df_plot['ano'], y = df_plot[variavel_2], color ='b')

    ax2.grid(False)
    ax.ticklabel_format(style='plain', axis='y')
    ax2.ticklabel_format(style='plain', axis='y')
    ax.legend(handles=[Line2D([], [], marker='_', color="g", label=y1_legend), Line2D([], [], marker='_', color="b", label=y2_legend)])

    ax.set_xticks(list(range(1984,2022,1)))
    ax2.set_xticks(list(range(1984,2022,1)))

    plt.xlim((1984, 2022))

    plt.ylim(bottom=0)



    plt.title(titulo, fontdict= {'size':13}, 
            y = 1.03, fontweight="bold")

    ax.set_xticklabels(
        labels=list(range(1984,2022,1)), rotation=70)
    ax2.set_xticklabels(
        labels=list(range(1984,2022,1)), rotation=70)

    ax.set_ylabel(y1_label, fontweight="bold")
    ax2.set_ylabel(y2_label, fontweight="bold")

    ax.yaxis.label.set_color('green')
    ax2.yaxis.label.set_color('blue')

    ax.tick_params(colors='green', axis='y') 
    ax2.tick_params(colors='blue', axis='y') 

    plt.show()

# %%
df_soja = df.loc[df['produto'] == 'Soja (em grão)']
df_soja
# Out:
#                municipio  cod_municipality regiao_intermediaria  \
# 768           Abaetetuba           1500107           Abaetetuba
# 769           Abaetetuba           1500107           Abaetetuba
# 770           Abaetetuba           1500107           Abaetetuba
# 771           Abaetetuba           1500107           Abaetetuba
# 772           Abaetetuba           1500107           Abaetetuba
# ...                  ...               ...                  ...
# 275960            Uruará           1508159             Altamira
# 275964             Vigia           1508209                Belém
# 275970             Viseu           1508308            Castanhal
# 275974  Vitória do Xingu           1508357             Altamira
# 275978          Xinguara           1508407             Redenção
#
#         cod_regiao_intermediaria  cod_regiao_imediata regiao_imediata  \
# 768                       150003                 1501           Belém
# 769                       150003                 1501           Belém
# 770                       150003                 1501           Belém
# 771                       150003                 1501           Belém
# 772                       150003                 1501           Belém
# ...                          ...                  ...             ...
# 275960                      1506               150018        Altamira
# 275964                      1501               150001           Belém
# 275970                      1502               150005        Bragança
# 275974                      1506               150018        Altamira
# 275978                      1504               150014        Xinguara
#
#                            tipo_producao  cod_variavel              variavel  \
# 768     Produto das lavouras temporárias         214.0  Quantidade produzida
# 769     Produto das lavouras temporárias         214.0  Quantidade produzida
# 770     Produto das lavouras temporárias         214.0  Quantidade produzida
# 771     Produto das lavouras temporárias         214.0  Quantidade produzida
# 772     Produto das lavouras temporárias         214.0  Quantidade produzida
# ...                                  ...           ...                   ...
# 275960  Produto das lavouras temporárias          39.0     Área de cobertura
# 275964  Produto das lavouras temporárias          39.0     Área de cobertura
# 275970  Produto das lavouras temporárias          39.0     Área de cobertura
# 275974  Produto das lavouras temporárias          39.0     Área de cobertura
# 275978  Produto das lavouras temporárias          39.0     Área de cobertura
#
#                produto    metrica        valor     ano
# 768     Soja (em grão)  Toneladas     0.000000  1974.0
# 769     Soja (em grão)  Toneladas     0.000000  1975.0
# 770     Soja (em grão)  Toneladas     0.000000  1976.0
# 771     Soja (em grão)  Toneladas     0.000000  1977.0
# 772     Soja (em grão)  Toneladas     0.000000  1978.0
# ...                ...        ...          ...     ...
# 275960  Soja (em grão)   Hectares  4051.138800  2021.0
# 275964  Soja (em grão)   Hectares     4.290440  2021.0
# 275970  Soja (em grão)   Hectares    63.458213  2021.0
# 275974  Soja (em grão)   Hectares    21.607314  2021.0
# 275978  Soja (em grão)   Hectares  1232.578321  2021.0
#
# [10653 rows x 13 columns]

# %%
plot_tipo_producao(df_soja, 'Produto das lavouras temporárias', 'Produto das lavouras temporárias',
                    'Quantidade produzida', 'Área de cobertura', titulo = 'Toneladas produzida e área de cobertura de soja no estado do Pará',
                   y1_label='Toneladas de soja', y2_label='Hectares de cobertura de soja',
                   y1_legend='Toneladas', y2_legend='Hectares',return_df= False)

# %%
df_corr_soja = plot_tipo_producao(df_soja, 'Produto das lavouras temporárias', 'Produto das lavouras temporárias',
                    'Quantidade produzida', 'Área de cobertura', titulo = 'Toneladas produzida e área de cobertura de soja no estado do Pará',
                    y1_label='Toneladas de soja', y2_label='Hectares de cobertura de soja',
                    y1_legend='Toneladas', y2_legend='Hectares',return_df= True)


sns.heatmap(df_corr_soja[['Quantidade produzida', 'Área de cobertura']].corr(),annot=True, cmap='cividis')
plt.xlabel('')
plt.ylabel('')
plt.title('Correlação de Pearson a quantidade produzida de soja e área\n de cobertura de soja no estado do Pará',
          y = 2)
# Out:
# Text(0.5, 2, 'Correlação de Pearson a quantidade produzida de soja e área\n de cobertura de soja no estado do Pará')

# %% [markdown]
# ## Silvicultura

# %%
df = pd.read_csv('/content/drive/MyDrive/Dados/unified-data/full_table_05022023.csv')
df.sample(15)
# Out:
#                   municipio  cod_municipality regiao_intermediaria  \
# 213723  São João de Pirabas           1507474             Capanema
# 43159           Brasil Novo           1501725             Altamira
# 79247            Dom Eliseu           1502939          Paragominas
# 271709            Castanhal           1502400            Castanhal
# 273160   Cachoeira do Piriá           1501956            Castanhal
# 90704           Igarapé-Açu           1503200            Castanhal
# 70995       Cumaru do Norte           1502764             Redenção
# 21833        Aurora do Pará           1500958          Paragominas
# 258621            Peixe-Boi           1505601            Castanhal
# 181689          Salinópolis           1506203             Capanema
# 145260            Oriximiná           1505304            Oriximiná
# 62560                Chaves           1502509               Breves
# 127599     Mojuí dos Campos           1504752             Santarém
# 94242             Inhangapi           1503408            Castanhal
# 35589             Benevides           1501501                Belém
#
#         cod_regiao_intermediaria  cod_regiao_imediata regiao_imediata  \
# 213723                    150006                 1502       Castanhal
# 43159                     150018                 1506        Altamira
# 79247                     150007                 1502       Castanhal
# 271709                      1502               150004       Castanhal
# 273160                      1502               150005        Bragança
# 90704                     150004                 1502       Castanhal
# 70995                     150012                 1504        Redenção
# 21833                     150007                 1502       Castanhal
# 258621                      1502               150006        Capanema
# 181689                    150006                 1502       Castanhal
# 145260                    150017                 1505        Santarém
# 62560                     150020                 1507          Breves
# 127599                    150015                 1505        Santarém
# 94242                     150004                 1502       Castanhal
# 35589                     150001                 1501           Belém
#
#                            tipo_producao  cod_variavel              variavel  \
# 213723  Produto das lavouras permanentes         214.0  Quantidade produzida
# 43159   Produto das lavouras permanentes         214.0  Quantidade produzida
# 79247   Produto das lavouras permanentes         214.0  Quantidade produzida
# 271709  Produto das lavouras permanentes          48.0     Área de cobertura
# 273160     Área de cobertura de Floresta           3.0     Área de cobertura
# 90704   Produto das lavouras temporárias         214.0  Quantidade produzida
# 70995   Produto das lavouras permanentes         214.0  Quantidade produzida
# 21833   Produto das lavouras permanentes         214.0  Quantidade produzida
# 258621  Produto das lavouras permanentes          48.0     Área de cobertura
# 181689  Produto das lavouras permanentes         214.0  Quantidade produzida
# 145260  Produto das lavouras permanentes         214.0  Quantidade produzida
# 62560                           Pecuária         105.0  Efetivo dos rebanhos
# 127599  Produto das lavouras permanentes         214.0  Quantidade produzida
# 94242   Produto das lavouras temporárias         214.0  Quantidade produzida
# 35589   Produto das lavouras temporárias         214.0  Quantidade produzida
#
#                        produto    metrica          valor     ano
# 213723               Tangerina  Toneladas       0.000000  2019.0
# 43159                 Maracujá  Toneladas     120.000000  1993.0
# 79247   Café (em grão) Arábica  Toneladas       0.000000  1994.0
# 271709                  Outros   Hectares     954.803856  2016.0
# 273160                 Florest   Hectares  137438.943163  2018.0
# 90704           Cana-de-açúcar  Toneladas       0.000000  1985.0
# 70995         Pimenta-do-reino  Toneladas       0.000000  1995.0
# 21833           Banana (cacho)  Toneladas       0.000000  1976.0
# 258621                  Outros   Hectares      62.119500  1998.0
# 181689      Cacau (em amêndoa)  Toneladas       0.000000  1995.0
# 145260    Café (em grão) Total  Toneladas       6.000000  1986.0
# 62560                 Bubalino    Cabeças   90000.000000  2008.0
# 127599                    Açaí  Toneladas       0.000000  1977.0
# 94242                   Cebola  Toneladas       0.000000  2019.0
# 35589                   Tomate  Toneladas       0.000000  2004.0

# %%
df.loc[(df['tipo_producao'] == 'Silvicultura')].metrica.unique()
# Out:
# array(['Toneladas', 'Metros cúbicos', 'Hectares'], dtype=object)

# %% [markdown]
# ### Toneladas

# %%
df_silvicultura_ton = df.loc[(df['metrica'] == 'Hectares') | (df['metrica'] == 'Toneladas')]

# %%
df_silvicultura_ton
# Out:
#                municipio  cod_municipality regiao_intermediaria  \
# 240           Abaetetuba           1500107           Abaetetuba
# 241           Abaetetuba           1500107           Abaetetuba
# 242           Abaetetuba           1500107           Abaetetuba
# 243           Abaetetuba           1500107           Abaetetuba
# 244           Abaetetuba           1500107           Abaetetuba
# ...                  ...               ...                  ...
# 275975  Vitória do Xingu           1508357             Altamira
# 275976          Xinguara           1508407             Redenção
# 275977          Xinguara           1508407             Redenção
# 275978          Xinguara           1508407             Redenção
# 275979          Xinguara           1508407             Redenção
#
#         cod_regiao_intermediaria  cod_regiao_imediata regiao_imediata  \
# 240                       150003                 1501           Belém
# 241                       150003                 1501           Belém
# 242                       150003                 1501           Belém
# 243                       150003                 1501           Belém
# 244                       150003                 1501           Belém
# ...                          ...                  ...             ...
# 275975                      1506               150018        Altamira
# 275976                      1504               150014        Xinguara
# 275977                      1504               150014        Xinguara
# 275978                      1504               150014        Xinguara
# 275979                      1504               150014        Xinguara
#
#                            tipo_producao  cod_variavel              variavel  \
# 240     Produto das lavouras temporárias         214.0  Quantidade produzida
# 241     Produto das lavouras temporárias         214.0  Quantidade produzida
# 242     Produto das lavouras temporárias         214.0  Quantidade produzida
# 243     Produto das lavouras temporárias         214.0  Quantidade produzida
# 244     Produto das lavouras temporárias         214.0  Quantidade produzida
# ...                                  ...           ...                   ...
# 275975  Produto das lavouras temporárias          41.0     Área de cobertura
# 275976     Área de cobertura de Floresta           3.0     Área de cobertura
# 275977                          Pastagem          15.0     Área de cobertura
# 275978  Produto das lavouras temporárias          39.0     Área de cobertura
# 275979  Produto das lavouras temporárias          41.0     Área de cobertura
#
#                produto    metrica          valor     ano
# 240           Abacaxi*  Toneladas       0.000000  1974.0
# 241           Abacaxi*  Toneladas       0.000000  1975.0
# 242           Abacaxi*  Toneladas       6.000000  1976.0
# 243           Abacaxi*  Toneladas       3.000000  1977.0
# 244           Abacaxi*  Toneladas      16.000000  1978.0
# ...                ...        ...            ...     ...
# 275975          Outros   Hectares     366.334757  2021.0
# 275976         Florest   Hectares   67297.304704  2021.0
# 275977           Pasto   Hectares  300973.161862  2021.0
# 275978  Soja (em grão)   Hectares    1232.578321  2021.0
# 275979          Outros   Hectares    2686.891111  2021.0
#
# [240412 rows x 13 columns]

# %%
plot_tipo_producao(df_silvicultura_ton, 'Silvicultura', 'Silvicultura',
                    'Quantidade produzida na silvicultura', 'Área de cobertura', titulo = 'Toneladas produzidas na Silvicultura e cobertura de\n de área de silvicultura no estado do Pará',
                    y1_label='Toneladas produzidas', y2_label='Hectares de cobertura Silvicultura',
                    y1_legend='Toneladas', y2_legend='Hectares',return_df= False)

# %%
df_corr_silvicultura_ton = plot_tipo_producao(df_silvicultura_ton, 'Silvicultura', 'Silvicultura',
                    'Quantidade produzida na silvicultura', 'Área de cobertura', titulo = 'Toneladas produzidas na Silvicultura e cobertura de\n de área de silviculta no estado do Pará',
                    y1_label='Toneladas produzidas', y2_label='Hectares de cobertura Silvicultura',
                    y1_legend='Toneladas', y2_legend='Hectares',return_df= True)


sns.heatmap(df_corr_soja[['Quantidade produzida na silvicultura', 'Área de cobertura']].corr(),annot=True, cmap='cividis')
plt.xlabel('')
plt.ylabel('')
plt.title('Correlação de Pearson entre toneladas produzidas na Silvicultura\n e cobertura de de área de silvicultura no estado do Pará',
          y = 2)
# Out:
# Text(0.5, 2, 'Correlação de Pearson entre toneladas produzidas na Silvicultura\n e cobertura de de área de silvicultura no estado do Pará')

# %% [markdown]
# ### Metros cúbicos

# %%
df_silvicultura_m3 = df.loc[(df['metrica'] == 'Hectares') | (df['metrica'] == 'Metros cúbicos')]

# %%
plot_tipo_producao(df_silvicultura_m3, 'Silvicultura', 'Silvicultura',
                    'Quantidade produzida na silvicultura', 'Área de cobertura', titulo = 'Metros cúbicos produzidos na Silvicultura e cobertura de\n de área de silvicultura no estado do Pará',
                    y1_label='Metros cúbicos produzidos', y2_label='Hectares de cobertura Silvicultura',
                    y1_legend='Metros cúbicos', y2_legend='Hectares',return_df= False)

# %%
df_corr_silvicultura_m3 = plot_tipo_producao(df_silvicultura_m3, 'Silvicultura', 'Silvicultura',
                    'Quantidade produzida na silvicultura', 'Área de cobertura', titulo = 'Metros cúbicos produzidos na Silvicultura e cobertura de\n de área de silvicultura no estado do Pará',
                    y1_label='Metros cúbicos produzidos', y2_label='Hectares de cobertura Silvicultura',
                    y1_legend='Metros cúbicos', y2_legend='Hectares',return_df= True)


sns.heatmap(df_corr_soja[['Quantidade produzida na silvicultura', 'Área de cobertura']].corr(),annot=True, cmap='cividis')
plt.xlabel('')
plt.ylabel('')
plt.title('Correlação de Pearson entre Metros cúbicos produzidos na Silvicultura\n e cobertura de de área de silvicultura no estado do Pará',
          y = 2)
# Out:
# Text(0.5, 2, 'Correlação de Pearson entre Metros cúbicos produzidos na Silvicultura\n e cobertura de de área de silvicultura no estado do Pará')

# %% [markdown]
# ## Lavouras permanentes

# %%
df_lavouras_perm = df.loc[df['produto'] != 'Soja (em grão)']

# %%
plot_tipo_producao(df_lavouras_perm, 'Produto das lavouras permanentes', 'Produto das lavouras permanentes',
                    'Quantidade produzida', 'Área de cobertura', titulo = 'Toneladas produzida e área de cobertura de lavouras permanentes no estado do Pará',
                    y1_label='Toneladas prroduzidas', y2_label='Hectares de lavouras permanentes',
                    y1_legend='Toneladas', y2_legend='Hectares',return_df= False)

# %%
df_corr_soja = plot_tipo_producao(df_lavouras_perm, 'Produto das lavouras temporárias', 'Produto das lavouras temporárias',
                    'Quantidade produzida', 'Área de cobertura', titulo = 'Toneladas produzida e área de cobertura de lavouras permanentes no estado do Pará',
                    y1_label='Toneladas prroduzidas', y2_label='Hectares de lavouras permanentes',
                    y1_legend='Toneladas', y2_legend='Hectares',return_df= True)


sns.heatmap(df_corr_soja[['Quantidade produzida', 'Área de cobertura']].corr(),annot=True, cmap='cividis')
plt.xlabel('')
plt.ylabel('')
plt.title('Correlação de Pearson a quantidade produzida de lavouras permanentes e área\n de cobertura de lavouras permanentes no estado do Pará',
          y = 2)
# Out:
# Text(0.5, 2, 'Correlação de Pearson a quantidade produzida de lavouras permanentes e área\n de cobertura de lavouras permanentes no estado do Pará')

# %% [markdown]
# ## Lavouras temporárias

# %%
df_lavouras_temp = df.loc[df['produto'] != 'Soja (em grão)']

# %%
plot_tipo_producao(df_lavouras_temp, 'Produto das lavouras temporárias', 'Produto das lavouras temporárias',
                    'Quantidade produzida', 'Área de cobertura', titulo = 'Toneladas produzida e área de cobertura de lavouras temporárias no estado do Pará',
                    y1_label='Toneladas prroduzidas', y2_label='Hectares de lavouras temporárias',
                    y1_legend='Toneladas', y2_legend='Hectares',return_df= False)

# %%
df_corr_soja = plot_tipo_producao(df_lavouras_perm, 'Produto das lavouras temporárias', 'Produto das lavouras temporárias',
                    'Quantidade produzida', 'Área de cobertura', titulo = 'Toneladas produzida e área de cobertura de lavouras permanentes no estado do Pará',
                    y1_label='Toneladas prroduzidas', y2_label='Hectares de lavouras permanentes',
                    y1_legend='Toneladas', y2_legend='Hectares',return_df= True)


sns.heatmap(df_corr_soja[['Quantidade produzida', 'Área de cobertura']].corr(),annot=True, cmap='cividis')
plt.xlabel('')
plt.ylabel('')
plt.title('Correlação de Pearson a quantidade produzida de lavouras permanentes e área\n de cobertura de lavouras permanentes no estado do Pará',
          y = 2)
