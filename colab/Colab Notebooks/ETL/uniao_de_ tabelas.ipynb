# %%
import pandas as pd
import numpy as np

# %%
cobertura = pd.read_csv('/content/drive/MyDrive/Dados/DW_Cobertura-da-terra/cobertura_formatados.csv')
cobertura.head()
# Out:
#     municipio  cod_municipality  cod_regiao_intermediaria  \
# 0  Abaetetuba           1500107                      1501
# 1  Abaetetuba           1500107                      1501
# 2  Abaetetuba           1500107                      1501
# 3  Abaetetuba           1500107                      1501
# 4  Abaetetuba           1500107                      1501
#
#   regiao_intermediaria  cod_regiao_imediata regiao_imediata  id_classe  \
# 0                Belém               150003      Abaetetuba          3
# 1                Belém               150003      Abaetetuba         15
# 2                Belém               150003      Abaetetuba         39
# 3                Belém               150003      Abaetetuba         41
# 4                Belém               150003      Abaetetuba         48
#
#              nome_classe           1985           1986  ...          2012  \
# 0       Forest Formation  100546.743913  101306.542189  ...  96645.692562
# 1                Pasture    5044.903800    4139.367871  ...  11054.932377
# 2              Soy Beans       0.000000       0.000000  ...      0.000000
# 3  Other Temporary Crops       0.000000       0.089356  ...     31.184249
# 4  Other Perennial Crops     638.716826     638.270027  ...   1099.478910
#
#            2013          2014          2015          2016          2017  \
# 0  95483.644518  94251.417993  93839.921283  93176.085484  92302.799622
# 1  11603.950761  13055.996662  13341.689949  13942.802844  14916.967394
# 2      0.000000      0.000000      0.000000      0.000000      0.000000
# 3     33.239327     27.073903     32.435191     31.184104     35.205075
# 4   2479.081339   2522.146984   2543.948126   2592.109960   2353.357306
#
#            2018          2019          2020          2021
# 0  92729.301835  93532.710235  93580.159176  93363.897514
# 1  14151.090292  13445.343754  13185.143045  13071.973225
# 2      0.000000      0.000000      0.000000      2.680636
# 3     28.235472     21.087233     22.516923     55.489021
# 4   2329.767996   2327.712880   2326.283216   2325.121680
#
# [5 rows x 45 columns]

# %%
cobertura.iloc[:,:8].columns
# Out:
# Index(['municipio', 'cod_municipality', 'cod_regiao_intermediaria',
#        'regiao_intermediaria', 'cod_regiao_imediata', 'regiao_imediata',
#        'id_classe', 'nome_classe'],
#       dtype='object')

# %%
ref = pd.melt(cobertura.iloc[:,8:])
print(f"Min: {ref['variable'].min()}\nMax: {ref['variable'].max()}")
# Out:
# Min: 1985
# Max: 2021

# %%
cobertura_long = pd.melt(cobertura, id_vars = cobertura.iloc[:,:8].columns, value_vars = cobertura.iloc[:,8:].columns)
cobertura_long.head()
# Out:
#     municipio  cod_municipality  cod_regiao_intermediaria  \
# 0  Abaetetuba           1500107                      1501
# 1  Abaetetuba           1500107                      1501
# 2  Abaetetuba           1500107                      1501
# 3  Abaetetuba           1500107                      1501
# 4  Abaetetuba           1500107                      1501
#
#   regiao_intermediaria  cod_regiao_imediata regiao_imediata  id_classe  \
# 0                Belém               150003      Abaetetuba          3
# 1                Belém               150003      Abaetetuba         15
# 2                Belém               150003      Abaetetuba         39
# 3                Belém               150003      Abaetetuba         41
# 4                Belém               150003      Abaetetuba         48
#
#              nome_classe variable          value
# 0       Forest Formation     1985  100546.743913
# 1                Pasture     1985    5044.903800
# 2              Soy Beans     1985       0.000000
# 3  Other Temporary Crops     1985       0.000000
# 4  Other Perennial Crops     1985     638.716826

# %%
sidra_df = pd.read_csv('/content/drive/MyDrive/Dados/Dados_SIDRA/table_full.csv')
sidra_df.head()
# Out:
#        cidade  cod_cidade    nome_rgi  cod_rgi  cod_rgint nome_rgint  \
# 0  Abaetetuba     1500107  Abaetetuba   150003       1501      Belém
# 1  Abaetetuba     1500107  Abaetetuba   150003       1501      Belém
# 2  Abaetetuba     1500107  Abaetetuba   150003       1501      Belém
# 3  Abaetetuba     1500107  Abaetetuba   150003       1501      Belém
# 4  Abaetetuba     1500107  Abaetetuba   150003       1501      Belém
#
#   tipo_producao  cod_variavel              variavel  cod_produto produto  \
# 0      Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# 1      Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# 2      Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# 3      Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
# 4      Pecuária         105.0  Efetivo dos rebanhos       2670.0  Bovino
#
#    cod_metrica  metrica valor     ano
# 0         24.0  Cabeças    28  1974.0
# 1         24.0  Cabeças    54  1975.0
# 2         24.0  Cabeças    47  1976.0
# 3         24.0  Cabeças    39  1977.0
# 4         24.0  Cabeças    10  1978.0

# %%
sidra_df['variavel'].unique()
# Out:
# array(['Efetivo dos rebanhos', 'Quantidade produzida', 'Área plantada',
#        'Área colhida', 'Área destinada à colheita',
#        'Quantidade produzida na silvicultura', nan], dtype=object)

# %%
sidra_df['produto'].unique()
# Out:
# array(['Bovino', 'Bubalino', 'Equino', 'Caprino', 'Ovino', 'Abacaxi*',
#        'Amendoim (em casca)', 'Arroz (em casca)', 'Batata-doce',
#        'Cana-de-açúcar', 'Cebola', 'Feijão (em grão)', 'Fumo (em folha)',
#        'Malva (fibra)', 'Melancia', 'Milho (em grão)', 'Soja (em grão)',
#        'Sorgo (em grão)', 'Tomate', 'Açaí', 'Banana (cacho)',
#        'Borracha (látex coagulado)', 'Cacau (em amêndoa)',
#        'Café (em grão) Total', 'Café (em grão) Arábica',
#        'Castanha de caju', 'Coco-da-baía*', 'Goiaba', 'Laranja', 'Limão',
#        'Mamão', 'Maracujá', 'Palmito', 'Pimenta-do-reino', 'Tangerina',
#        'Urucum (semente)', '1.1.1 - Carvão vegetal de eucalipto',
#        '1.2.1 - Lenha de eucalipto',
#        '1.3.1.1 - Madeira em tora de eucalipto para papel e celulose',
#        '1.3.2.1 - Madeira em tora de eucalipto para outras finalidades',
#        '1.3.2.3 - Madeira em tora de outras espécies para outras finalidades',
#        nan], dtype=object)

# %%
sidra_df.sample(10)
# Out:
#                           cidade  cod_cidade    nome_rgi  cod_rgi  cod_rgint  \
# 610326       São Miguel do Guamá     1507607   Castanhal   150004       1502
# 288769              Jacareacanga     1503754    Itaituba   150016       1505
# 93700                   Belterra     1501451    Santarém   150015       1505
# 493194                 Rio Maria     1506161    Xinguara   150014       1504
# 667305                   Tucuruí     1508100     Tucuruí   150011       1503
# 357359          Mojuí dos Campos     1504752    Santarém   150015       1505
# 22                    Abaetetuba     1500107  Abaetetuba   150003       1501
# 566782  São Domingos do Araguaia     1507151      Marabá   150009       1503
# 702331                       NaN     4104253    Curitiba   410001       4101
# 76727                      Baião     1501204     Tucuruí   150011       1503
#
#        nome_rgint                     tipo_producao  cod_variavel  \
# 610326  Castanhal  Produto das lavouras permanentes         216.0
# 288769   Santarém  Produto das lavouras temporárias         109.0
# 93700    Santarém  Produto das lavouras temporárias         109.0
# 493194   Redenção                      Silvicultura         142.0
# 667305     Marabá  Produto das lavouras permanentes         216.0
# 357359   Santarém  Produto das lavouras temporárias         216.0
# 22          Belém                          Pecuária         105.0
# 566782     Marabá                          Pecuária         105.0
# 702331   Curitiba                               NaN           NaN
# 76727      Marabá  Produto das lavouras permanentes         214.0
#
#                                     variavel  cod_produto  \
# 610326                          Área colhida       2747.0
# 288769                         Área plantada       2702.0
# 93700                          Área plantada       2697.0
# 493194  Quantidade produzida na silvicultura      33250.0
# 667305                          Área colhida       2722.0
# 357359                          Área colhida       2703.0
# 22                      Efetivo dos rebanhos       2670.0
# 566782                  Efetivo dos rebanhos       2677.0
# 702331                                   NaN          NaN
# 76727                   Quantidade produzida       2727.0
#
#                            produto  cod_metrica         metrica valor     ano
# 610326            Urucum (semente)       1006.0        Hectares     -  2004.0
# 288769            Feijão (em grão)          NaN             NaN   ...  1978.0
# 93700                       Cebola       1006.0        Hectares     -  2003.0
# 493194  1.2.1 - Lenha de eucalipto       1016.0  Metros cúbicos   ...  2016.0
# 667305          Cacau (em amêndoa)       1006.0        Hectares    42  1989.0
# 357359             Fumo (em folha)       1006.0        Hectares   ...  1989.0
# 22                          Bovino         24.0         Cabeças  5050  1996.0
# 566782                       Ovino         24.0         Cabeças   300  1996.0
# 702331                         NaN          NaN             NaN   NaN     NaN
# 76727                Coco-da-baía*       1017.0       Toneladas   141  1993.0

# %%
cobertura_long['nome_classe'].unique()
# Out:
# array(['Forest Formation', 'Pasture', 'Soy Beans',
#        'Other Temporary Crops', 'Other Perennial Crops',
#        'Forest Plantation'], dtype=object)

# %%
sidra_df['tipo_producao'].unique()
# Out:
# array(['Pecuária', 'Produto das lavouras temporárias',
#        'Produto das lavouras permanentes', 'Silvicultura', nan],
#       dtype=object)

# %%
for index, row in cobertura_long.iterrows():
    if row['nome_classe'] == 'Forest Formation':
        cobertura_long.loc[index,'variavel'] = 'Área de cobertura'
        cobertura_long.loc[index,'produto'] = 'Florest'
        cobertura_long.loc[index,'tipo_producao'] = 'Área de cobertura de Floresta'
    elif row['nome_classe'] == 'Pasture':
        cobertura_long.loc[index,'variavel'] = 'Área de cobertura'
        cobertura_long.loc[index,'produto'] = 'Pasto'
        cobertura_long.loc[index,'tipo_producao'] = 'Pastagem'
    elif row['nome_classe'] == 'Soy Beans':
        cobertura_long.loc[index,'variavel'] = 'Área de cobertura'
        cobertura_long.loc[index,'produto'] = 'Soja (em grão)'
        cobertura_long.loc[index,'tipo_producao'] = 'Produto das lavouras temporárias'
    elif row['nome_classe'] == 'Other Temporary Crops':
        cobertura_long.loc[index,'variavel'] = 'Área de cobertura'
        cobertura_long.loc[index,'produto'] = 'Outros'
        cobertura_long.loc[index,'tipo_producao'] = 'Produto das lavouras temporárias'
    elif row['nome_classe'] == 'Other Perennial Crops':
        cobertura_long.loc[index,'variavel'] = 'Área de cobertura'
        cobertura_long.loc[index,'produto'] = 'Outros'
        cobertura_long.loc[index,'tipo_producao'] = 'Produto das lavouras permanentes'
    elif row['nome_classe'] == 'Silvicultura':
        cobertura_long.loc[index,'variavel'] = 'Área de cobertura'
        cobertura_long.loc[index,'produto'] = 'Área de cobertura da Silvicultura'
        cobertura_long.loc[index,'tipo_producao'] = 'Silvicultura'

# %%
cobertura_long.columns = ['municipio', 'cod_municipality',	'cod_regiao_intermediaria',
                          'regiao_intermediaria',	'cod_regiao_imediata',	'regiao_imediata',	'cod_variavel',
                          'nome_classe',	'ano',	'valor',	'variavel',	'produto',	'tipo_producao']
cobertura_long = cobertura_long.drop(columns = 'nome_classe')
sidra_df = sidra_df.drop(columns = ['cod_produto', 'cod_metrica', 'metrica'])

# %%
cobertura_long
# Out:
#               municipio  cod_municipality  cod_regiao_intermediaria  \
# 0            Abaetetuba           1500107                      1501
# 1            Abaetetuba           1500107                      1501
# 2            Abaetetuba           1500107                      1501
# 3            Abaetetuba           1500107                      1501
# 4            Abaetetuba           1500107                      1501
# ...                 ...               ...                       ...
# 27560  Vitória do Xingu           1508357                      1506
# 27561          Xinguara           1508407                      1504
# 27562          Xinguara           1508407                      1504
# 27563          Xinguara           1508407                      1504
# 27564          Xinguara           1508407                      1504
#
#       regiao_intermediaria  cod_regiao_imediata regiao_imediata  cod_variavel  \
# 0                    Belém               150003      Abaetetuba             3
# 1                    Belém               150003      Abaetetuba            15
# 2                    Belém               150003      Abaetetuba            39
# 3                    Belém               150003      Abaetetuba            41
# 4                    Belém               150003      Abaetetuba            48
# ...                    ...                  ...             ...           ...
# 27560             Altamira               150018        Altamira            41
# 27561             Redenção               150014        Xinguara             3
# 27562             Redenção               150014        Xinguara            15
# 27563             Redenção               150014        Xinguara            39
# 27564             Redenção               150014        Xinguara            41
#
#         ano          valor           variavel         produto  \
# 0      1985  100546.743913  Área de cobertura         Florest
# 1      1985    5044.903800  Área de cobertura           Pasto
# 2      1985       0.000000  Área de cobertura  Soja (em grão)
# 3      1985       0.000000  Área de cobertura          Outros
# 4      1985     638.716826  Área de cobertura          Outros
# ...     ...            ...                ...             ...
# 27560  2021     366.334757  Área de cobertura          Outros
# 27561  2021   67297.304704  Área de cobertura         Florest
# 27562  2021  300973.161862  Área de cobertura           Pasto
# 27563  2021    1232.578321  Área de cobertura  Soja (em grão)
# 27564  2021    2686.891111  Área de cobertura          Outros
#
#                           tipo_producao
# 0         Área de cobertura de Floresta
# 1                              Pastagem
# 2      Produto das lavouras temporárias
# 3      Produto das lavouras temporárias
# 4      Produto das lavouras permanentes
# ...                                 ...
# 27560  Produto das lavouras temporárias
# 27561     Área de cobertura de Floresta
# 27562                          Pastagem
# 27563  Produto das lavouras temporárias
# 27564  Produto das lavouras temporárias
#
# [27565 rows x 12 columns]

# %%
sidra_df.columns = ['municipio', 'cod_municipality', 'regiao_intermediaria',
                    'cod_regiao_intermediaria', 'cod_regiao_imediata', 'regiao_imediata',
                    'tipo_producao', 'cod_variavel', 'variavel', 'produto', 'valor', 'ano']
cobertura_long = cobertura_long[sidra_df.columns]

# %%
unified_df = pd.concat([sidra_df, cobertura_long])

# %%
unified_df.to_csv('/content/drive/MyDrive/Dados/unified-data/full_table.csv', index=False)
